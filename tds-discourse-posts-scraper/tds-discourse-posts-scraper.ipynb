# %%
import asyncio
from playwright.async_api import async_playwright
import os
import getpass
import json
from urllib.parse import urlparse

LINKS_FILE = "filtered_post_links.txt"
OUTPUT_DIR = "knowledge"

async def scrape_post_data(page, url):
    await page.goto(url)
    # Wait for posts to load
    await page.wait_for_selector("article[data-post-id] div.cooked", timeout=30000)

    posts = await page.locator("article[data-post-id]").all()
    thread_data = {
        "url": url,
        "main_post": {},
        "replies": []
    }

    for i, post in enumerate(posts):
        post_id = await post.get_attribute("data-post-id")
        content = await post.locator("div.cooked").inner_text()
        timestamp = await post.locator("span.relative-date").inner_text()

        # Extract all links in the post content
        links = await post.locator("div.cooked a").all_inner_texts()

        post_data = {
            "post_id": post_id, 
            "content": content.strip(),
            "date": timestamp,
            "links": links
        }

        if i == 0:
            thread_data["main_post"] = post_data
        else:
            thread_data["replies"].append(post_data)

    return thread_data

async def main():
    email = input("Enter your IITM email: ")
    password = getpass.getpass("Enter your IITM password (hidden): ")

    # Read all URLs from the links file
    with open(LINKS_FILE, "r") as f:
        urls = [line.strip() for line in f if line.strip()]

    # Create output directory if not exists
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        context = await browser.new_context()
        page = await context.new_page()

        # Login step using the first URL
        await page.goto(urls[0])
        await page.fill('#login-account-name', email)
        await page.fill('#login-account-password', password)
        await page.click('#login-button')
        await page.wait_for_url(urls[0], timeout=20000)
        print("✅ Logged in.")

        # Loop through all URLs and scrape
        for url in urls:
            print(f"🔄 Scraping: {url}")
            try:
                thread_data = await scrape_post_data(page, url)

                # Extract thread ID from URL for filename
                path = urlparse(url).path.strip("/").split("/")
                thread_id = path[1] if len(path) > 1 else "unknown"
                out_file = os.path.join(OUTPUT_DIR, f"thread_{thread_id}.json")

                with open(out_file, "w", encoding="utf-8") as f:
                    json.dump(thread_data, f, indent=2, ensure_ascii=False)

                print(f"✅ Saved to {out_file}")

            except Exception as e:
                print(f"❌ Failed to scrape {url}: {e}")

        await browser.close()

# Run the async main function (use this if running in a script or Jupyter)
if __name__ == "__main__":
    await main()
# Out:
# Enter your IITM email:  sapta
# Enter your IITM password (hidden):  ········
# ✅ Logged in.
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/about-the-tools-in-data-science-category/23335/42
# ✅ Saved to knowledge\thread_about-the-tools-in-data-science-category.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/end-term-mock-tds-jan-25/172333/11
# ✅ Saved to knowledge\thread_end-term-mock-tds-jan-25.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/pyq-haversine/172546/1
# ✅ Saved to knowledge\thread_pyq-haversine.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/what-to-do-if-peer-has-not-allowed-access-and-the-deadline-is-over-for-peer-review-in-project-2/172471/4
# ✅ Saved to knowledge\thread_what-to-do-if-peer-has-not-allowed-access-and-the-deadline-is-over-for-peer-review-in-project-2.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-not-submitted-issue/172497/2
# ✅ Saved to knowledge\thread_project-1-not-submitted-issue.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/graded-assignment-6/169283/46
# ✅ Saved to knowledge\thread_graded-assignment-6.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga7-data-visualisation-discussion-thread-tds-jan-2025/169888/31
# ✅ Saved to knowledge\thread_ga7-data-visualisation-discussion-thread-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/email-in-ga-7/172021/2
# ✅ Saved to knowledge\thread_email-in-ga-7.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/pyq-doubt/172373/2
# ✅ Saved to knowledge\thread_pyq-doubt.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-ga7-score-missing/171500/9
# ✅ Saved to knowledge\thread_tds-ga7-score-missing.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/according-to-tds-rule-14-b/172254/4
# ✅ Saved to knowledge\thread_according-to-tds-rule-14-b.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/end-term-tds/171668/13
# ✅ Saved to knowledge\thread_end-term-tds.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/why-failed/171672/5
# ✅ Saved to knowledge\thread_why-failed.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-solution-repository-link/171999/2
# ✅ Saved to knowledge\thread_project-1-solution-repository-link.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-discrepancy-regarding-mit-license/171485/10
# ✅ Saved to knowledge\thread_project-1-discrepancy-regarding-mit-license.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-llm-based-automation-agent-discussion-thread-tds-jan-2025/164277/662
# ✅ Saved to knowledge\thread_project-1-llm-based-automation-agent-discussion-thread-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-tds-score-not-showing-i/168916/24
# ✅ Saved to knowledge\thread_project-1-tds-score-not-showing-i.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/peer-review-clarificaiton/171541/5
# ✅ Saved to knowledge\thread_peer-review-clarificaiton.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/clarification-on-api-endpoint-correction-in-submission/171525/4
# ✅ Saved to knowledge\thread_clarification-on-api-endpoint-correction-in-submission.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga7-peer-grading-clarification/171515/1
# ✅ Saved to knowledge\thread_ga7-peer-grading-clarification.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-2-how-to-test-questions-from-the-gas/171422/2
# ✅ Saved to knowledge\thread_project-2-how-to-test-questions-from-the-gas.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/scores-and-end-semester-exam/171473/1
# ✅ Saved to knowledge\thread_scores-and-end-semester-exam.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/request-for-extension-on-tds-project-2-deadline/171428/2
# ✅ Saved to knowledge\thread_request-for-extension-on-tds-project-2-deadline.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/successfully-completed-tds-project-2-seeking-feedback-demonstration-session/171054/6
# ✅ Saved to knowledge\thread_successfully-completed-tds-project-2-seeking-feedback-demonstration-session.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-jan-25-imp-announcement-for-project-2/170413/6
# ✅ Saved to knowledge\thread_tds-jan-25-imp-announcement-for-project-2.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga4-bonus-marks/170309/2
# ✅ Saved to knowledge\thread_ga4-bonus-marks.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/concerns-regarding-various-issues-graded-assignments-project-doubts-and-roe-score-updates/170147/5
# ✅ Saved to knowledge\thread_concerns-regarding-various-issues-graded-assignments-project-doubts-and-roe-score-updates.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/problem-with-tds-ga-scores/170131/2
# ✅ Saved to knowledge\thread_problem-with-tds-ga-scores.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/clarification-on-passing-criteria-for-tds-january-2025-term/169807/2
# ✅ Saved to knowledge\thread_clarification-on-passing-criteria-for-tds-january-2025-term.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/programming-quiz-1-in-student-dashboard-label-for-roe-scores-showing-absent-or-incorrect/169369/29
# ✅ Saved to knowledge\thread_programming-quiz-1-in-student-dashboard-label-for-roe-scores-showing-absent-or-incorrect.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/remote-online-exam-tds-jan-2025/168832/124
# ✅ Saved to knowledge\thread_remote-online-exam-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/revised-dates-tds-jan-2025/168506/6
# ✅ Saved to knowledge\thread_revised-dates-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/thursday-live-session/169393/3
# ✅ Saved to knowledge\thread_thursday-live-session.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/live-session-recorded-or-not/169456/2
# ✅ Saved to knowledge\thread_live-session-recorded-or-not.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/solve-this-roe-mistake-pls/169352/2
# ✅ Saved to knowledge\thread_solve-this-roe-mistake-pls.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga5-data-preparation-discussion-thread-tds-jan-2025/166576/107
# ✅ Saved to knowledge\thread_ga5-data-preparation-discussion-thread-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/disparity-in-tds-ga-5-scores/169247/4
# ✅ Saved to knowledge\thread_disparity-in-tds-ga-5-scores.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/whats-the-actual-purpose-of-impossible-roe-exam/99838/3
# ✅ Saved to knowledge\thread_whats-the-actual-purpose-of-impossible-roe-exam.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/mock-roe-1-2-3-4-tds-jan-2025/168449/82
# ✅ Saved to knowledge\thread_mock-roe-1-2-3-4-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-2-tds-solver-shared-data-pool/169045/7
# ✅ Saved to knowledge\thread_project-2-tds-solver-shared-data-pool.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/roe-timing-overlaps-with-java-oppe/168537/5
# ✅ Saved to knowledge\thread_roe-timing-overlaps-with-java-oppe.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/unable-to-attend-the-roe/168987/2
# ✅ Saved to knowledge\thread_unable-to-attend-the-roe.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/roe-common-snippets-repo-feb-2025/168901/5
# ✅ Saved to knowledge\thread_roe-common-snippets-repo-feb-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/solving-roe-realtime/168943/5
# ✅ Saved to knowledge\thread_solving-roe-realtime.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/not-recieved-the-roe-link-mail/168825/5
# ✅ Saved to knowledge\thread_not-recieved-the-roe-link-mail.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/is-it-fair-to-consider-20-weightage-of-such-exam-which-is-impossible-to-solve-in-given-time-i-e-roe/141413/17
# ✅ Saved to knowledge\thread_is-it-fair-to-consider-20-weightage-of-such-exam-which-is-impossible-to-solve-in-given-time-i-e-roe.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/concerns-regarding-tds-course-difficulty-and-grading-fairness/168476/17
# ✅ Saved to knowledge\thread_concerns-regarding-tds-course-difficulty-and-grading-fairness.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-w4-q3/166651/1
# ✅ Saved to knowledge\thread_tds-w4-q3.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/opening-previous-ga-just-for-practise/168515/4
# ✅ Saved to knowledge\thread_opening-previous-ga-just-for-practise.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/create-a-question-solving-groups-for-roe/168567/15
# ✅ Saved to knowledge\thread_create-a-question-solving-groups-for-roe.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/clarification-regarding-mock-roe-timings/168384/11
# ✅ Saved to knowledge\thread_clarification-regarding-mock-roe-timings.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-roe-exam-date-shift/168458/8
# ✅ Saved to knowledge\thread_tds-roe-exam-date-shift.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-module-6/168482/2
# ✅ Saved to knowledge\thread_tds-module-6.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/q3-ga5-not-accepting-right-answer/168011/9
# ✅ Saved to knowledge\thread_q3-ga5-not-accepting-right-answer.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/request-for-a-functionality-to-revise-the-gas-of-tds/168310/1
# ✅ Saved to knowledge\thread_request-for-a-functionality-to-revise-the-gas-of-tds.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-2-and-week-6-assignment/168303/4
# ✅ Saved to knowledge\thread_project-2-and-week-6-assignment.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/roe-instructions-request/168142/8
# ✅ Saved to knowledge\thread_roe-instructions-request.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga4-data-sourcing-discussion-thread-tds-jan-2025/165959/392
# ✅ Saved to knowledge\thread_ga4-data-sourcing-discussion-thread-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/my-score-are-still-not-updated/168143/2
# ✅ Saved to knowledge\thread_my-score-are-still-not-updated.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/question-9-of-tds-week-5-ga/168057/2
# ✅ Saved to knowledge\thread_question-9-of-tds-week-5-ga.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga5-score-not-reflecting-in-the-page-after-deadline/168017/2
# ✅ Saved to knowledge\thread_ga5-score-not-reflecting-in-the-page-after-deadline.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/about-tds-course/167878/3
# ✅ Saved to knowledge\thread_about-tds-course.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/graded-assignments-dashboard-scores-incorrect-missing/166816/76
# ✅ Saved to knowledge\thread_graded-assignments-dashboard-scores-incorrect-missing.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/inconsistent-information-in-the-grading-document-and-the-website/167679/2
# ✅ Saved to knowledge\thread_inconsistent-information-in-the-grading-document-and-the-website.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-casual-banter/167344/14
# ✅ Saved to knowledge\thread_project-1-casual-banter.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/important-dockerfile-submitted-as-dockerfile-rest-everything-is-working-fine/167415/6
# ✅ Saved to knowledge\thread_important-dockerfile-submitted-as-dockerfile-rest-everything-is-working-fine.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-1-submission-marked-as-fail-despite-having-dockerfile-image/167471/11
# ✅ Saved to knowledge\thread_project-1-submission-marked-as-fail-despite-having-dockerfile-image.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/request-to-consider-my-last-submission-for-tds-project-1/167410/2
# ✅ Saved to knowledge\thread_request-to-consider-my-last-submission-for-tds-project-1.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/just-some-background-test/167699/1
# ✅ Saved to knowledge\thread_just-some-background-test.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/request-for-postponing-the-project-1-deadline-official-response-extended/166866/28
# ✅ Saved to knowledge\thread_request-for-postponing-the-project-1-deadline-official-response-extended.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/regarding-project1-for-file-not-detecting-after-sending-post-request/167172/14
# ✅ Saved to knowledge\thread_regarding-project1-for-file-not-detecting-after-sending-post-request.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-project-1-release-information-required/164214/3
# ✅ Saved to knowledge\thread_tds-project-1-release-information-required.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/regarding-github-mail-for-project/166891/2
# ✅ Saved to knowledge\thread_regarding-github-mail-for-project.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/sudo-permission-needed-to-create-data-folder-in-root/167072/2
# ✅ Saved to knowledge\thread_sudo-permission-needed-to-create-data-folder-in-root.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/for-project-1/166593/5
# ✅ Saved to knowledge\thread_for-project-1.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/project-structure/166738/1
# ✅ Saved to knowledge\thread_project-structure.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/i-have-doubt-in-q10/166647/2
# ✅ Saved to knowledge\thread_i-have-doubt-in-q10.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/doubt-in-ga4-q7/166634/8
# ✅ Saved to knowledge\thread_doubt-in-ga4-q7.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/chat-gpt-new-release/166498/1
# ✅ Saved to knowledge\thread_chat-gpt-new-release.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/where-can-i-find-the-tds-ga1-after-the-submission-date-has-passed/165416/3
# ✅ Saved to knowledge\thread_where-can-i-find-the-tds-ga1-after-the-submission-date-has-passed.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/questions-closed-ga/165433/7
# ✅ Saved to knowledge\thread_questions-closed-ga.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga2-deployment-tools-discussion-thread-tds-jan-2025/161120/178
# ✅ Saved to knowledge\thread_ga2-deployment-tools-discussion-thread-tds-jan-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/llm-what-rocket-science-going-on-here/166303/3
# ✅ Saved to knowledge\thread_llm-what-rocket-science-going-on-here.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/doubts-in-q7-q8/166357/1
# ✅ Saved to knowledge\thread_doubts-in-q7-q8.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/reattempt-graded-assignment-after-deadline/166349/1
# ✅ Saved to knowledge\thread_reattempt-graded-assignment-after-deadline.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/meet-with-anand-tds-faculty-wed-5-feb-10-30-am-2-30-pm/165687/5
# ✅ Saved to knowledge\thread_meet-with-anand-tds-faculty-wed-5-feb-10-30-am-2-30-pm.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/access-to-notebooks/166100/2
# ✅ Saved to knowledge\thread_access-to-notebooks.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/graded-assignment-1-submission-not-shown/165396/24
# ✅ Saved to knowledge\thread_graded-assignment-1-submission-not-shown.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/best-practices-for-virtual-environments-and-dependency-management-in-python/165922/4
# ✅ Saved to knowledge\thread_best-practices-for-virtual-environments-and-dependency-management-in-python.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/live-session-agenda-30-01-2025/165830/1
# ✅ Saved to knowledge\thread_live-session-agenda-30-01-2025.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/course-drop/165746/2
# ✅ Saved to knowledge\thread_course-drop.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/live-sessions-regarding-project-1/165593/2
# ✅ Saved to knowledge\thread_live-sessions-regarding-project-1.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-jan-2025-calender-accesss-and-video-lecture-access-in-portal/163158/6
# ✅ Saved to knowledge\thread_tds-jan-2025-calender-accesss-and-video-lecture-access-in-portal.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ga2-deadline/165142/2
# ✅ Saved to knowledge\thread_ga2-deadline.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/agenda-for-todays-live-session-flask-tutorial/164869/4
# ✅ Saved to knowledge\thread_agenda-for-todays-live-session-flask-tutorial.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/drop-course-window-for-tds/164737/1
# ✅ Saved to knowledge\thread_drop-course-window-for-tds.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-assignment-week-2/164462/1
# ✅ Saved to knowledge\thread_tds-assignment-week-2.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/agenda-for-todays-21-01-2025-session/164460/1
# ✅ Saved to knowledge\thread_agenda-for-todays-21-01-2025-session.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/regarding-droping-from-tds/164291/3
# ✅ Saved to knowledge\thread_regarding-droping-from-tds.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/issues-in-tds-and-replacement-with-another-course/164147/3
# ✅ Saved to knowledge\thread_issues-in-tds-and-replacement-with-another-course.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/score-keeps-resetting-to-0/163765/8
# ✅ Saved to knowledge\thread_score-keeps-resetting-to-0.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/need-clarity/164205/1
# ✅ Saved to knowledge\thread_need-clarity.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/ta-sessions-youtube-links/164089/2
# ✅ Saved to knowledge\thread_ta-sessions-youtube-links.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/need-friends/163381/4
# ✅ Saved to knowledge\thread_need-friends.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/regarding-extra-material-information-resources-for-the-upcoming-project/163241/2
# ✅ Saved to knowledge\thread_regarding-extra-material-information-resources-for-the-upcoming-project.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/answers-are-not-getting-saved/163224/2
# ✅ Saved to knowledge\thread_answers-are-not-getting-saved.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-iitm-certified-books/163147/2
# ✅ Saved to knowledge\thread_tds-iitm-certified-books.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/can-i-take-the-end-term-exam-without-submitting-assignments-if-i-missed-it-due-to-an-emergency/161072/4
# ✅ Saved to knowledge\thread_can-i-take-the-end-term-exam-without-submitting-assignments-if-i-missed-it-due-to-an-emergency.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/way-of-conduction-of-exam/163144/2
# ✅ Saved to knowledge\thread_way-of-conduction-of-exam.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/tds-calendar-link-not-found/162425/3
# ✅ Saved to knowledge\thread_tds-calendar-link-not-found.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/contribute-to-my-open-source-llm-classroom-assignment-evaluator/161214/5
# ✅ Saved to knowledge\thread_contribute-to-my-open-source-llm-classroom-assignment-evaluator.json
# 🔄 Scraping: https://discourse.onlinedegree.iitm.ac.in/t/which-subject-to-choose-in-jan-term/161071/4
# ✅ Saved to knowledge\thread_which-subject-to-choose-in-jan-term.json
